# %% [markdown]
# # Gesture recognition with random forest

# %% [markdown]
# ### Libraries

# %%
import pandas as pd
from sklearn import datasets
from sklearn.model_selection import train_test_split
from mlxtend.plotting import plot_decision_regions
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ### Load data

# %%
df = pd.read_csv('datasets/1667171758.794016.csv').drop(['Unnamed: 0'], axis=1)
df.head(10)
# Out:
#    x0   y0  x1   y1  x2  y2  x3  y3  x4  y4  ...  y16  x17  y17  x18  y18  \
# 0   5  124   0  105   2  81  11  66  17  54  ...   98   25   89   27   86
# 1   6  124   0  106   2  82  11  65  17  54  ...   96   26   87   27   84
# 2   5  124   0  106   2  83  11  68  17  55  ...   99   26   89   27   85
# 3   6  126   0  109   2  85  11  69  17  56  ...   98   27   89   28   84
# 4   5  125   0  107   2  84  10  67  17  54  ...  100   25   89   28   84
# 5   6  125   0  107   3  83  11  67  17  53  ...  101   26   89   28   85
# 6   6  126   0  108   2  84  11  67  17  54  ...   98   27   88   28   84
# 7   5  124   0  106   2  82  10  67  17  54  ...   99   25   89   26   85
# 8   5  125   0  108   2  84  10  67  17  55  ...  100   26   89   27   85
# 9   5  124   0  105   2  82  11  67  17  55  ...   99   26   88   27   84
#
#    x19  y19  x20  y20           Y
# 0   22   95   19  101  Mouse Move
# 1   22   93   20   99  Mouse Move
# 2   21   95   18  102  Mouse Move
# ...

# %%
df.tail(10)
# Out:
#      x0  y0  x1  y1  x2  y2  x3  y3  x4  y4  ...  y16  x17  y17  x18  y18  \
# 693  21  88   9  83   0  66   1  53  10  48  ...   62   35   46   31   59
# 694  21  85  10  81   0  65   2  51  10  45  ...   59   35   42   31   56
# 695  21  81  10  76   0  60   2  45  12  42  ...   55   36   43   34   47
# 696  21  85  10  81   0  63   1  47  11  43  ...   59   35   43   31   57
# 697  20  88   9  80   0  63   1  46  10  42  ...   55   34   50   34   45
# 698  20  90   9  80   0  63   2  47  11  43  ...   56   34   51   34   46
# 699  19  93   8  84   0  66   2  50  11  46  ...   61   34   54   34   48
# 700  20  95   9  86   0  67   2  50  11  47  ...   63   34   53   34   48
# 701  20  97   9  86   0  68   3  53  13  49  ...   64   35   53   34   54
# 702  19  99   9  90   0  71   2  56  12  51  ...   64   35   52   33   55
#
#      x19  y19  x20  y20           Y
# 693   28   70   27   70  Left Click
# 694   28   67   27   67  Left Click
# 695   30   59   29   62  Left Click
# ...

# %%
x = df.drop(['Y'], axis=1)
y = df['Y']
print(x.shape, y.shape)
# Out:
# (703, 42) (703,)

# %% [markdown]
# ### Train-Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.9, random_state=1, stratify=y)

# %% [markdown]
# ### Model

# %%
forest = RandomForestClassifier(criterion='log_loss',
n_estimators=50,
n_jobs=-1)

# %% [markdown]
# ### Train model

# %%
forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='log_loss', n_estimators=50, n_jobs=-1)

# %% [markdown]
# ### Predict test

# %%
y_pred = forest.predict(X_test)
print('Accuracy: %.3f' % accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.998

# %%
df2 = pd.read_csv('datasets/1667170770.376018.csv')
x = df2.drop(['Unnamed: 0', 'Y'], axis=1)
y = df2['Y']
print(x.head(2))
print(x.shape, y.shape)
# Out:
#    x0   y0  x1   y1  x2   y2  x3  y3  x4  y4  ...  x16  y16  x17  y17  x18  \
# 0  22  111  10  100   4   85   0  72   1  61  ...   18   94   37   75   26
# 1  26  185   9  165   0  128   1  97   0  72  ...   21  130   42  111   34
#
#    y18  x19  y19  x20  y20
# 0   87   23   96   24  100
# 1   92   30  110   31  122
#
# [2 rows x 42 columns]
# (4459, 42) (4459,)

# %%
y_pred = forest.predict(x)
print('Accuracy: %.3f' % accuracy_score(y, y_pred))
# Out:
# Accuracy: 0.798
